# %% [markdown]
# ## Install Packages

# %%
# !pip install pycaret==2.0
# Out:
# ...
#      |████████████████████████████████| 255 kB 2.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 102 kB 5.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 271 kB 5.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 636 kB 4.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 366 kB 7.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 67.3 MB 53.3 MB/s eta 0:00:01     |██████████████████████████████  | 63.0 MB 53.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 23.9 MB 96.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 248 kB 99.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 60 kB 19.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.3 MB 95.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 14.2 MB 102.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 285 kB 84.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.7 MB 97.3 MB/s eta 0:00:01
# ...

# %%
# !pip install seaborn
# Out:
# WARNING: Ignoring invalid distribution -cipy (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -cipy (/opt/conda/lib/python3.7/site-packages)
# ...
#   Using cached seaborn-0.11.1-py3-none-any.whl (285 kB)
# ...
# WARNING: Ignoring invalid distribution -cipy (/opt/conda/lib/python3.7/site-packages)
# ...
# WARNING: Ignoring invalid distribution -cipy (/opt/conda/lib/python3.7/site-packages)
# ...
# WARNING: Ignoring invalid distribution -cipy (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -cipy (/opt/conda/lib/python3.7/site-packages)

# %%
###import

import re
import os

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# "magic" command to make plots show up in the notebook
# %matplotlib inline 
import pycaret

# # # # we want to increase it, because in this case there are a lot of column names
# pd.options.display.max_rows = 300
# pd.options.display.max_columns = 1000
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-d4c8281f95f6> in <module>
#       6 import pandas as pd
#       7 import numpy as np
# ----> 8 import seaborn as sns
#       9 import matplotlib.pyplot as plt
#      10
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
df = pd.read_csv('./data/lgb_selected_default.csv')
# df.head()

# %%
from pycaret.classification import *

# %% [markdown]
# ## Make sample
# - Since using original df outrange our RAM capacity
# - Make sample of df for Pycaret to comparing Algorithms

# %%
df_sample = df.copy()
df_sample.sample(frac=0.1, replace=True, random_state=2020)
# Out:
#          Unnamed: 0  total_rec_prncp  out_prncp  last_pymnt_amnt  \
# 1765768     1765768          2053.41       0.00           309.96
# 1482051     1482051          1594.85    5405.15           219.62
# 1948278     1948278         26000.00       0.00         12709.22
# 542811       542811         15000.00       0.00          8870.32
# 1508989     1508989           879.86    3120.14           131.05
# ...             ...              ...        ...              ...
# 290527       290527         15000.00       0.00           167.45
# 440588       440588          9128.86   21871.14          1029.35
# 1253817     1253817         28000.00       0.00         17229.28
# 916527       916527           993.52       0.00           111.01
# 1311732     1311732         21200.00       0.00         13112.42
#
#          last_fico_range_high  funded_amnt  funded_amnt_inv  \
# 1765768                 654.0      13000.0          13000.0
# 1482051                 709.0       7000.0           7000.0
# ...

# %% [markdown]
# ## Setting up Pycaret

# %%
clf = setup(data = df_sample, target = 'loan_status', silent = True)
# Out:
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_6d142_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6d142_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6d142_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_6d142_row0_col1" class="data row0 col1" >7721</td>
#             </tr>
#             <tr>
#                         <th id="T_6d142_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6d142_row1_col0" class="data row1 col0" >Target Type</td>
#                         <td id="T_6d142_row1_col1" class="data row1 col1" >Binary</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# ## Comparing Models

# %%
best_3 = compare_models(sort = 'AUC', fold=5, n_select = 3)
# Out:
# <style  type="text/css" >
#     #T_e5084_ th {
#           text-align: left;
# ...
