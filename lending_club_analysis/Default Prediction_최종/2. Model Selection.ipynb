# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import re
import os

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline 
import pycaret

# %%
path_read ="/Users/a06411/Documents/data_hub/lending_club/lgb_selected.pkl"

# %%
df = pd.read_pickle(path_read)
# df.drop(['Unnamed: 0'],1,inplace=True)

# %%
df.shape
# Out:
# (1382351, 63)

# %%
df.head()
# Out:
#    int_rate    dti  annual_inc  mo_sin_old_rev_tl_op  acc_open_past_24mths  \
# 0     13.99   5.91     55000.0                 128.0                   4.0
# 1     11.99  16.06     65000.0                 192.0                   4.0
# 2     10.78  10.78     63000.0                 184.0                   6.0
# 4     22.45  25.37    104433.0                 210.0                  10.0
# 5     13.44  10.20     34000.0                  54.0                   0.0
#
#    loan_amnt  emp_length  addr_state  revol_bal  term  ...  total_bal_ex_mort  \
# 0     3600.0           1          38     2765.0     0  ...             7746.0
# 1    24700.0           1          41    21470.0     0  ...            39475.0
# 2    20000.0           1          14     7869.0     1  ...            18696.0
# 4    10400.0           3          38    21929.0     1  ...            95768.0
# 5    11950.0           4          10     8822.0     0  ...            12798.0
#
#    mths_since_last_major_derog  inq_fi  mths_since_rcnt_il  inq_last_12m  \
# 0                         30.0     3.0                21.0           4.0
# 1                         -1.0     0.0                19.0           6.0
# 2                         -1.0     2.0                19.0           1.0
# 4                         -1.0     2.0                14.0           3.0
# 5                         -1.0     0.0               338.0           0.0
#
#    mths_since_last_delinq  num_bc_tl  loan_status   issue_d        id
# 0                    30.0        5.0            0  Dec-2015  68407277
# 1                     6.0       17.0            0  Dec-2015  68355089
# 2                    -1.0        4.0            0  Dec-2015  68341763
# 4                    12.0        9.0            0  Dec-2015  68476807
# 5                    -1.0        2.0            0  Dec-2015  68426831
#
# [5 rows x 63 columns]

# %% [markdown]
# ## 파이캐럿 autoML로 처리하기

# %%
from pycaret.classification import *

# %% [markdown]
# ## Make sample
# - Since using original df outrange our RAM capacity
# - Make sample of df for Pycaret to comparing Algorithms

# %%
df_sample = df.copy()

# %%
df_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41471 entries, 1054037 to 386477
# Data columns (total 63 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   int_rate                     41471 non-null  float64
#  1   dti                          41471 non-null  float64
#  2   annual_inc                   41471 non-null  float64
#  3   mo_sin_old_rev_tl_op         41471 non-null  float64
#  4   acc_open_past_24mths         41471 non-null  float64
#  5   loan_amnt                    41471 non-null  float64
#  6   emp_length                   41471 non-null  int64
#  7   addr_state                   41471 non-null  int64
#  8   revol_bal                    41471 non-null  float64
#  9   term                         41471 non-null  int64
#  10  sub_grade                    41471 non-null  int64
#  11  funded_amnt_inv              41471 non-null  float64
#  12  installment                  41471 non-null  float64
#  13  purpose                      41471 non-null  int64
#  14  total_rev_hi_lim             41471 non-null  float64
#  15  fico_range_low               41471 non-null  float64
#  16  debt_settlement_flag         41471 non-null  int64
#  17  mort_acc                     41471 non-null  float64
#  18  total_bc_limit               41471 non-null  float64
#  19  home_ownership               41471 non-null  int64
#  20  avg_cur_bal                  41471 non-null  float64
#  21  all_util                     41471 non-null  float64
#  22  mths_since_recent_bc         41471 non-null  float64
#  23  total_acc                    41471 non-null  float64
#  24  open_acc_6m                  41471 non-null  float64
#  25  bc_util                      41471 non-null  float64
#  26  num_actv_rev_tl              41471 non-null  float64
#  27  funded_amnt                  41471 non-null  float64
#  28  hardship_flag                41471 non-null  int64
#  29  num_rev_tl_bal_gt_0          41471 non-null  float64
#  30  mths_since_recent_inq        41471 non-null  float64
#  31  inq_last_6mths               41471 non-null  float64
#  32  num_il_tl                    41471 non-null  float64
#  33  mo_sin_old_il_acct           41471 non-null  float64
#  34  num_rev_accts                41471 non-null  float64
#  35  num_tl_120dpd_2m             41471 non-null  float64
#  36  total_il_high_credit_limit   41471 non-null  float64
#  37  application_type             41471 non-null  int64
#  38  revol_util                   41471 non-null  float64
#  39  tot_hi_cred_lim              41471 non-null  float64
#  40  delinq_2yrs                  41471 non-null  float64
#  41  mo_sin_rcnt_tl               41471 non-null  float64
#  42  num_actv_bc_tl               41471 non-null  float64
#  43  mths_since_last_record       41471 non-null  float64
#  44  percent_bc_gt_75             41471 non-null  float64
#  45  bc_open_to_buy               41471 non-null  float64
#  46  max_bal_bc                   41471 non-null  float64
#  47  grade                        41471 non-null  int64
#  48  open_rv_24m                  41471 non-null  float64
#  49  mo_sin_rcnt_rev_tl_op        41471 non-null  float64
#  50  pct_tl_nvr_dlq               41471 non-null  float64
#  51  verification_status          41471 non-null  int64
#  52  tot_cur_bal                  41471 non-null  float64
#  53  total_bal_ex_mort            41471 non-null  float64
#  54  mths_since_last_major_derog  41471 non-null  float64
#  55  inq_fi                       41471 non-null  float64
#  56  mths_since_rcnt_il           41471 non-null  float64
#  57  inq_last_12m                 41471 non-null  float64
#  58  mths_since_last_delinq       41471 non-null  float64
#  59  num_bc_tl                    41471 non-null  float64
#  60  loan_status                  41471 non-null  int64
#  61  issue_d                      41471 non-null  object
#  62  id                           41471 non-null  object
# dtypes: float64(49), int64(12), object(2)
# memory usage: 21.3+ MB

# %%
df_sample = df_sample.sample(frac=0.03, random_state=20)

# %%
df_sample.shape
# Out:
# (41471, 63)

# %%
df_sample.columns[:-2]
# Out:
# Index(['int_rate', 'dti', 'annual_inc', 'mo_sin_old_rev_tl_op',
#        'acc_open_past_24mths', 'loan_amnt', 'emp_length', 'addr_state',
#        'revol_bal', 'term', 'sub_grade', 'funded_amnt_inv', 'installment',
#        'purpose', 'total_rev_hi_lim', 'fico_range_low', 'debt_settlement_flag',
#        'mort_acc', 'total_bc_limit', 'home_ownership', 'avg_cur_bal',
#        'all_util', 'mths_since_recent_bc', 'total_acc', 'open_acc_6m',
#        'bc_util', 'num_actv_rev_tl', 'funded_amnt', 'hardship_flag',
#        'num_rev_tl_bal_gt_0', 'mths_since_recent_inq', 'inq_last_6mths',
#        'num_il_tl', 'mo_sin_old_il_acct', 'num_rev_accts', 'num_tl_120dpd_2m',
#        'total_il_high_credit_limit', 'application_type', 'revol_util',
#        'tot_hi_cred_lim', 'delinq_2yrs', 'mo_sin_rcnt_tl', 'num_actv_bc_tl',
#        'mths_since_last_record', 'percent_bc_gt_75', 'bc_open_to_buy',
#        'max_bal_bc', 'grade', 'open_rv_24m', 'mo_sin_rcnt_rev_tl_op',
#        'pct_tl_nvr_dlq', 'verification_status', 'tot_cur_bal',
#        'total_bal_ex_mort', 'mths_since_last_major_derog', 'inq_fi',
#        'mths_since_rcnt_il', 'inq_last_12m', 'mths_since_last_delinq',
#        'num_bc_tl', 'loan_status'],
#       dtype='object')

# %% [markdown]
# ## Setting up Pycaret

# %%
st_clf = setup(data = df_sample[df_sample.columns[:-2]], target = 'loan_status')
# Out:
# <style type="text/css">
# #T_08886_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_08886">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_08886_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_08886_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_08886_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_08886_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_08886_row0_col1" class="data row0 col1" >3562</td>
#     </tr>
#     <tr>
#       <th id="T_08886_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_08886_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_08886_row1_col1" class="data row1 col1" >loan_status</td>
#     </tr>
#     <tr>
#       <th id="T_08886_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_08886_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_08886_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_08886_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_08886_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_08886_row3_col1" class="data row3 col1" >(41471, 61)</td>
#     </tr>
#     <tr>
#       <th id="T_08886_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_08886_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_08886_row4_col1" class="data row4 col1" >(41471, 61)</td>
#     </tr>
#     <tr>
#       <th id="T_08886_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_08886_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_08886_row5_col1" class="data row5 col1" >(29029, 61)</td>
#     </tr>
#     <tr>
#       <th id="T_08886_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_08886_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_08886_row6_col1" class="data row6 col1" >(12442, 61)</td>
#     </tr>
#     <tr>
#       <th id="T_08886_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_08886_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_08886_row7_col1" class="data row7 col1" >60</td>
#     </tr>
#     <tr>
#       <th id="T_08886_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_08886_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_08886_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_08886_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_08886_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_08886_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_08886_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_08886_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_08886_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_08886_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_08886_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_08886_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_08886_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_08886_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_08886_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_08886_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_08886_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_08886_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_08886_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_08886_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_08886_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_08886_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_08886_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_08886_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_08886_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_08886_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_08886_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_08886_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_08886_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_08886_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_08886_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_08886_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_08886_row18_col1" class="data row18 col1" >7853</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Comparing Models

# %%
best_3 = compare_models(sort ='AUC', fold=3, n_select = 3)
# Out:
# <style type="text/css">
# #T_8b766 th {
#   text-align: left;
# }
# #T_8b766_row0_col0, #T_8b766_row0_col1, #T_8b766_row0_col3, #T_8b766_row0_col4, #T_8b766_row0_col5, #T_8b766_row0_col6, #T_8b766_row1_col0, #T_8b766_row1_col2, #T_8b766_row1_col3, #T_8b766_row1_col4, #T_8b766_row1_col5, #T_8b766_row1_col6, #T_8b766_row1_col7, #T_8b766_row2_col0, #T_8b766_row2_col1, #T_8b766_row2_col2, #T_8b766_row2_col3, #T_8b766_row2_col4, #T_8b766_row2_col5, #T_8b766_row2_col6, #T_8b766_row2_col7, #T_8b766_row3_col0, #T_8b766_row3_col1, #T_8b766_row3_col2, #T_8b766_row3_col3, #T_8b766_row3_col4, #T_8b766_row3_col5, #T_8b766_row3_col6, #T_8b766_row3_col7, #T_8b766_row4_col0, #T_8b766_row4_col1, #T_8b766_row4_col2, #T_8b766_row4_col3, #T_8b766_row4_col4, #T_8b766_row4_col5, #T_8b766_row4_col6, #T_8b766_row4_col7, #T_8b766_row5_col0, #T_8b766_row5_col1, #T_8b766_row5_col2, #T_8b766_row5_col3, #T_8b766_row5_col4, #T_8b766_row5_col5, #T_8b766_row5_col6, #T_8b766_row5_col7, #T_8b766_row6_col0, #T_8b766_row6_col1, #T_8b766_row6_col2, #T_8b766_row6_col3, #T_8b766_row6_col4, #T_8b766_row6_col5, #T_8b766_row6_col6, #T_8b766_row6_col7, #T_8b766_row7_col0, #T_8b766_row7_col1, #T_8b766_row7_col2, #T_8b766_row7_col3, #T_8b766_row7_col4, #T_8b766_row7_col5, #T_8b766_row7_col7, #T_8b766_row8_col0, #T_8b766_row8_col1, #T_8b766_row8_col2, #T_8b766_row8_col3, #T_8b766_row8_col5, #T_8b766_row8_col6, #T_8b766_row8_col7, #T_8b766_row9_col0, #T_8b766_row9_col1, #T_8b766_row9_col2, #T_8b766_row9_col4, #T_8b766_row9_col6, #T_8b766_row9_col7, #T_8b766_row10_col0, #T_8b766_row10_col1, #T_8b766_row10_col2, #T_8b766_row10_col3, #T_8b766_row10_col4, #T_8b766_row10_col5, #T_8b766_row10_col6, #T_8b766_row10_col7, #T_8b766_row11_col0, #T_8b766_row11_col1, #T_8b766_row11_col2, #T_8b766_row11_col3, #T_8b766_row11_col4, #T_8b766_row11_col5, #T_8b766_row11_col6, #T_8b766_row11_col7, #T_8b766_row12_col0, #T_8b766_row12_col1, #T_8b766_row12_col2, #T_8b766_row12_col3, #T_8b766_row12_col4, #T_8b766_row12_col5, #T_8b766_row12_col6, #T_8b766_row12_col7, #T_8b766_row13_col0, #T_8b766_row13_col1, #T_8b766_row13_col2, #T_8b766_row13_col3, #T_8b766_row13_col4, #T_8b766_row13_col5, #T_8b766_row13_col6, #T_8b766_row13_col7, #T_8b766_row14_col0, #T_8b766_row14_col1, #T_8b766_row14_col2, #T_8b766_row14_col3, #T_8b766_row14_col4, #T_8b766_row14_col5, #T_8b766_row14_col6, #T_8b766_row14_col7, #T_8b766_row15_col0, #T_8b766_row15_col1, #T_8b766_row15_col2, #T_8b766_row15_col3, #T_8b766_row15_col4, #T_8b766_row15_col5, #T_8b766_row15_col6, #T_8b766_row15_col7 {
#   text-align: left;
# }
# #T_8b766_row0_col2, #T_8b766_row0_col7, #T_8b766_row1_col1, #T_8b766_row7_col6, #T_8b766_row8_col4, #T_8b766_row9_col3, #T_8b766_row9_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_8b766_row0_col8, #T_8b766_row1_col8, #T_8b766_row2_col8, #T_8b766_row3_col8, #T_8b766_row4_col8, #T_8b766_row5_col8, #T_8b766_row6_col8, #T_8b766_row7_col8, #T_8b766_row8_col8, #T_8b766_row9_col8, #T_8b766_row10_col8, #T_8b766_row11_col8, #T_8b766_row12_col8, #T_8b766_row14_col8, #T_8b766_row15_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_8b766_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_8b766">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b766_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8b766_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_8b766_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_8b766_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_8b766_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_8b766_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_8b766_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_8b766_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_8b766_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b766_level0_row0" class="row_heading level0 row0" >catboost</th>
#       <td id="T_8b766_row0_col0" class="data row0 col0" >CatBoost Classifier</td>
#       <td id="T_8b766_row0_col1" class="data row0 col1" >0.8140</td>
#       <td id="T_8b766_row0_col2" class="data row0 col2" >0.7527</td>
#       <td id="T_8b766_row0_col3" class="data row0 col3" >0.2031</td>
#       <td id="T_8b766_row0_col4" class="data row0 col4" >0.7201</td>
#       <td id="T_8b766_row0_col5" class="data row0 col5" >0.3167</td>
#       <td id="T_8b766_row0_col6" class="data row0 col6" >0.2463</td>
#       <td id="T_8b766_row0_col7" class="data row0 col7" >0.3132</td>
#       <td id="T_8b766_row0_col8" class="data row0 col8" >2.5800</td>
#     </tr>
#     <tr>
#       <th id="T_8b766_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_8b766_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_8b766_row1_col1" class="data row1 col1" >0.8147</td>
#       <td id="T_8b766_row1_col2" class="data row1 col2" >0.7513</td>
#       <td id="T_8b766_row1_col3" class="data row1 col3" >0.1776</td>
#       <td id="T_8b766_row1_col4" class="data row1 col4" >0.7807</td>
#       <td id="T_8b766_row1_col5" class="data row1 col5" >0.2892</td>
#       <td id="T_8b766_row1_col6" class="data row1 col6" >0.2286</td>
#       <td id="T_8b766_row1_col7" class="data row1 col7" >0.3129</td>
#       <td id="T_8b766_row1_col8" class="data row1 col8" >3.6933</td>
#     </tr>
#     <tr>
#       <th id="T_8b766_level0_row2" class="row_heading level0 row2" >lda</th>
#       <td id="T_8b766_row2_col0" class="data row2 col0" >Linear Discriminant Analysis</td>
#       <td id="T_8b766_row2_col1" class="data row2 col1" >0.8139</td>
#       <td id="T_8b766_row2_col2" class="data row2 col2" >0.7487</td>
#       <td id="T_8b766_row2_col3" class="data row2 col3" >0.1888</td>
#       <td id="T_8b766_row2_col4" class="data row2 col4" >0.7447</td>
#       <td id="T_8b766_row2_col5" class="data row2 col5" >0.3010</td>
#       <td id="T_8b766_row2_col6" class="data row2 col6" >0.2354</td>
#       <td id="T_8b766_row2_col7" class="data row2 col7" >0.3103</td>
#       <td id="T_8b766_row2_col8" class="data row2 col8" >0.1567</td>
#     </tr>
#     <tr>
#       <th id="T_8b766_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_8b766_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_8b766_row3_col1" class="data row3 col1" >0.8112</td>
#       <td id="T_8b766_row3_col2" class="data row3 col2" >0.7459</td>
#       <td id="T_8b766_row3_col3" class="data row3 col3" >0.1955</td>
#       <td id="T_8b766_row3_col4" class="data row3 col4" >0.6981</td>
#       <td id="T_8b766_row3_col5" class="data row3 col5" >0.3053</td>
#       <td id="T_8b766_row3_col6" class="data row3 col6" >0.2342</td>
#       <td id="T_8b766_row3_col7" class="data row3 col7" >0.2985</td>
#       <td id="T_8b766_row3_col8" class="data row3 col8" >0.2833</td>
#     </tr>
#     <tr>
#       <th id="T_8b766_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_8b766_row4_col0" class="data row4 col0" >Ada Boost Classifier</td>
#       <td id="T_8b766_row4_col1" class="data row4 col1" >0.8121</td>
#       <td id="T_8b766_row4_col2" class="data row4 col2" >0.7451</td>
#       <td id="T_8b766_row4_col3" class="data row4 col3" >0.1886</td>
#       <td id="T_8b766_row4_col4" class="data row4 col4" >0.7204</td>
#       <td id="T_8b766_row4_col5" class="data row4 col5" >0.2987</td>
#       <td id="T_8b766_row4_col6" class="data row4 col6" >0.2309</td>
#       <td id="T_8b766_row4_col7" class="data row4 col7" >0.3011</td>
#       <td id="T_8b766_row4_col8" class="data row4 col8" >0.8167</td>
#     </tr>
#     <tr>
#       <th id="T_8b766_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_8b766_row5_col0" class="data row5 col0" >Extra Trees Classifier</td>
#       <td id="T_8b766_row5_col1" class="data row5 col1" >0.8121</td>
#       <td id="T_8b766_row5_col2
