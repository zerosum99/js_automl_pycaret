# %%
# ##import
import warnings
warnings.filterwarnings('ignore')

import os, sys, gc, warnings, random, datetime

import pandas as pd
import numpy as np

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import roc_auc_score, f1_score, precision_recall_curve, accuracy_score
from sklearn.model_selection import KFold, StratifiedKFold

import lightgbm as lgb

from IPython.display import display
from bayes_opt import BayesianOptimization



from sklearn import metrics
from sklearn.model_selection import train_test_split


pd.set_option('display.max_columns', 200)

# %%
###load data

# %%
# Load Data with selected features
X = pd.read_csv('./data/lgb_selected_default.csv')
# Targets
y = X['loan_status']

# Remove Labels from Dataframe
X.drop(['loan_status'], axis = 1, inplace = True)
# Final Data Shapes
print(X.shape)
print(y.shape)
# Out:
# (2260668, 41)
# (2260668,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2, random_state = 2020)

# %% [markdown]
# ## Bayesian Optimization

# %%
bounds = {
    'learning_rate': (0.002, 0.2),
    'num_leaves': (50, 500), 
    'bagging_fraction' : (0.1, 1),
    'feature_fraction' : (0.1, 1),
    'min_child_weight': (0.001, 0.5),   
    'min_data_in_leaf': (20, 170),
    'max_depth': (15, 20),
    'reg_alpha': (0.1, 2), 
    'reg_lambda': (0.1, 2)
}

# %%
def train_model(learning_rate, 
                num_leaves,
                bagging_fraction, 
                feature_fraction, 
                min_child_weight,
                min_data_in_leaf,
                max_depth,
                reg_alpha,
                reg_lambda):
    
    params = {'learning_rate': learning_rate,
              'num_leaves': int(num_leaves), 
              'bagging_fraction' : bagging_fraction,
              'feature_fraction' : feature_fraction,
              'min_child_weight': min_child_weight,   
              'min_data_in_leaf': int(min_data_in_leaf),
              'max_depth': int(max_depth),
              'reg_alpha': reg_alpha, 
              'reg_lambda': reg_lambda,
              'objective': 'binary',
              'boosting_type': 'gbdt',
              'random_state': 2021,
              'verbosity': -1,
              'metric': 'auc'}
    
    trn_data = lgb.Dataset(X_train, y_train)
    val_data = lgb.Dataset(X_test, y_test)
    model = lgb.train(params, trn_data, 5000, valid_sets = [trn_data, val_data], verbose_eval=0, early_stopping_rounds=50)
    # Returning auc score
    return model.best_score['valid_1']['auc']

# %%
optimizer = BayesianOptimization(f=train_model, pbounds=bounds, random_state=2021)


optimizer.maximize(init_points=10, n_iter=10)
# Out:
# |   iter    |  target   | baggin... | featur... | learni... | max_depth | min_ch... | min_da... | num_le... | reg_alpha | reg_la... |
# -------------------------------------------------------------------------------------------------------------------------------------
# |  1        |  0.9968   |  0.6454   |  0.76     |  0.02951  |  16.56    |  0.4986   |  39.22    |  130.5    |  1.531    |  1.358    |
# |  2        |  0.9929   |  0.8059   |  0.1872   |  0.0136   |  19.81    |  0.3087   |  32.99    |  302.6    |  1.271    |  1.931    |
# |  3        |  0.9967   |  0.6169   |  0.434    |  0.09152  |  16.01    |  0.2851   |  49.26    |  312.7    |  1.005    |  1.084    |
# |  4        |  0.9968   |  0.8408   |  0.759    |  0.01567  |  18.36    |  0.3221   |  144.2    |  142.0    |  1.273    |  1.274    |
# |  5        |  0.9967   |  0.371    |  0.8846   |  0.1188   |  19.91    |  0.2217   |  38.95    |  279.0    |  0.9204   |  1.84     |
# |  6        |  0.9966   |  0.7381   |  0.9016   |  0.1186   |  18.18    |  0.1718   |  143.6    |  187.3    |  0.6843   |  0.4825   |
# |  7        |  0.9968   |  0.3386   |  0.6858   |  0.03261  |  16.94    |  0.3242   |  147.2    |  78.73    |  0.8874   |  0.7313   |
# |  8        |  0.9966   |  0.7492   |  0.5265   |  0.1601   |  15.45    |  0.4374   |  136.5    |  397.2    |  0.2199   |  1.229    |
# |  9        |  0.9968   |  0.8132   |  0.3467   |  0.07546  |  19.27    |  0.3397   |  133.2    |  237.8    |  0.7097   |  0.8074   |
# |  10       |  0.9966   |  0.3478   |  0.7116   |  0.1172   |  19.85    |  0.2083   |  69.57    |  485.0    |  1.669    |  0.6803   |
# |  11       |  0.9966   |  0.4532   |  0.3818   |  0.1344   |  17.99    |  0.4627   |  132.2    |  237.0    |  1.456    |  0.9968   |
# |  12       |  0.9965   |  0.205    |  0.7298   |  0.1993   |  17.81    |  0.3653   |  60.98    |  323.3    |  1.74     |  1.848    |
# |  13       |  0.9967   |  0.4391   |  0.2888   |  0.1338   |  18.67    |  0.4108   |  147.2    |  246.9    |  0.1553   |  0.8508   |
# |  14       |  0.9968   |  0.8617   |  0.3139   |  0.04668  |  19.28    |  0.1854   |  132.1    |  253.9    |  1.245    |  1.276    |
# |  15       |  0.9967   |  0.2524   |  0.4881   |  0.08264  |  19.58    |  0.2808   |  149.5    |  227.2    |  1.3      |  1.455    |
# |  16       |  0.9967   |  0.9291   |  0.9009   |  0.05353  |  18.49    |  0.3983   |  43.26    |  261.2    |  0.8446   |  1.593    |
# |  17       |  0.9957   |  0.7373   |  0.4629   |  0.007252 |  18.3     |  0.4404   |  146.7    |  160.8    |  1.418    |  1.252    |
# |  18       |  0.9967   |  0.3642   |  0.968    |  0.05233  |  18.36    |  0.02341  |  140.0    |  125.6    |  1.747    |  0.1145   |
# |  19       |  0.9968   |  0.1353   |  0.747    |  0.01084  |  19.64    |  0.3028   |  159.2    |  130.6    |  0.731    |  1.333    |
# |  20       |  0.9967   |  0.8605   |  0.9976   |  0.06408  |  15.2     |  0.4594   |  155.0    |  112.6    |  1.599    |  1.126    |
# =====================================================================================================================================

# %%
optimizer.max['params']
# Out:
# {'bagging_fraction': 0.1352596638277066,
#  'feature_fraction': 0.7469934533565048,
#  'learning_rate': 0.01084443459402704,
#  'max_depth': 19.635409113512498,
#  'min_child_weight': 0.30275249989439823,
#  'min_data_in_leaf': 159.1573696978958,
#  'num_leaves': 130.56800786083414,
#  'reg_alpha': 0.7309683176011929,
#  'reg_lambda': 1.3332030058536595}

# %%
### Use optimized parameters as parameter for model
lgb_params = {'num_leaves': int(optimizer.max['params']['num_leaves']),
              'bagging_fraction' : optimizer.max['params']['bagging_fraction'],
              'feature_fraction' : optimizer.max['params']['feature_fraction'],
              'learning_rate' :  optimizer.max['params']['learning_rate'],
              'max_depth' : int(optimizer.max['params']['max_depth']),
              'min_child_weight' :  optimizer.max['params']['min_child_weight'],
              'min_data_in_leaf' : int(optimizer.max['params']['min_data_in_leaf']),
              'num_leaves' : int(optimizer.max['params']['num_leaves']),
              'reg_alpha': optimizer.max['params']['reg_alpha'],
              'reg_lambda' : optimizer.max['params']['reg_lambda'],
            'objective': 'binary',
        'boosting_type': 'gbdt',
        'verbose': 10,
        'metric': 'auc'
              
    
}

# %% [markdown]
# ## Make Real Prediction (Params from Bayesian Optimization)

# %%
df = pd.read_pickle('../input/lending-club-feature-selection/lgb_selected.pkl')

train , test = train_test_split(df,test_size = 0.2, random_state = 2020)
y_train = train.pop('loan_status')
y_test = test.pop('loan_status')
train.reset_index(drop=True, inplace=True)
test.reset_index(drop=True, inplace=True)
y_train.reset_index(drop=True, inplace=True)
y_test.reset_index(drop=True, inplace=True)

remove_features = ['id','loan_status']
features = [col for col in list(train) if col not in remove_features]

# %%
def seed_everything(seed=0):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    
SEED = 42
seed_everything(SEED)

# %%
def make_lgb_prediction(train, y, test, features, categorical_features='auto', model_params=None, folds=5):
    def lgb_f1_score(y_hat, data):
        y_true = data.get_label()
        y_hat = np.round(y_hat) 
        return 'f1', f1_score(y_true, y_hat, average='binary'), True
    
    skf = KFold(n_splits=folds, random_state=SEED, shuffle=True)
    
    x_train = train[features]
    x_test = test[features]

    y_preds = np.zeros(x_test.shape[0])
    y_oof = np.zeros(x_train.shape[0])
    score = 0

    feature_importance = pd.DataFrame()
    feature_importance['feature'] = features

    for fold, (tr_idx, val_idx) in enumerate(skf.split(x_train, y)):
        print(f'Fold: {fold+1}')

        x_tr, x_val = x_train.loc[tr_idx, features], x_train.loc[val_idx, features]
        y_tr, y_val = y[tr_idx], y[val_idx]

        print(x_tr.shape, x_val.shape)

        dtrain = lgb.Dataset(x_tr, label=y_tr)
        dvalid = lgb.Dataset(x_val, label=y_val)

        clf = lgb.train(
            model_params,
            dtrain,
            valid_sets=[dtrain, dvalid],
            categorical_feature=categorical_features,
            verbose_eval=200,
            early_stopping_rounds=100,
            feval=lgb_f1_score
        )

        feature_importance[f'fold_{fold+1}'] = clf.feature_importance()

        y_pred_val = clf.predict(x_val)

        y_oof[val_idx] = y_pred_val
        print(f"Fold {fold + 1} | F1 Score: {f1_score(y_val, np.round(y_pred_val), average='micro')}")

        score += f1_score(y_val, np.round(y_pred_val), average='micro') / folds
        y_preds += clf.predict(x_test) / folds

        del x_tr, x_val, y_tr, y_val
        gc.collect()

    print(f"\nMean F1 score = {score}")
    print(f"OOF F1 score = {f1_score(y, np.round(y_oof), average='micro')}")
    
    return y_oof, y_preds, feature_importance

# %%
y_oof_lgb, y_preds_lgb, fi_lgb = make_lgb_prediction(train, y_train, test, features, model_params=lgb_params)
# Out:
# Fold: 1
# (1446827, 40) (361707, 40)
# [LightGBM] [Info] Number of positive: 189108, number of negative: 1257719
# [LightGBM] [Debug] Dataset::GetMultiBinFromSparseFeatures: sparse rate 0.915726
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.228427
# [LightGBM] [Debug] init for col-wise cost 0.095866 seconds, init for row-wise cost 0.815909 seconds
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.891230 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6678
# [LightGBM] [Info] Number of data points in the train set: 1446827, number of used features: 40
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.130705 -> initscore=-1.894737
# [LightGBM] [Info] Start training from score -1.894737
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# Training until validation scores don't improve for 100 rounds
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.995434	training's f1: 0.945352	valid_1's auc: 0.995208	valid_1's f1: 0.944391
# Fold 1 | F1 Score: 0.9862706555305814
# Fold: 2
# (1446827, 40) (361707, 40)
# [LightGBM] [Info] Number of positive: 189133, number of negative: 1257694
# [LightGBM] [Debug] Dataset::GetMultiBinFromSparseFeatures: sparse rate 0.915621
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.228441
# [LightGBM] [Debug] init for col-wise cost 0.085707 seconds, init for row-wise cost 0.345381 seconds
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.418084 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6672
# [LightGBM] [Info] Number of data points in the train set: 1446827, number of used features: 40
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.130723 -> initscore=-1.894585
# [LightGBM] [Info] Start training from score -1.894585
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# Training until validation scores don't improve for 100 rounds
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# Did not meet early stopping. Best iteration is:
# [98]	training's auc: 0.99551	training's f1: 0.943807	valid_1's auc: 0.995258	valid_1's f1: 0.94158
# Fold 2 | F1 Score: 0.9856237230686716
# Fold: 3
# (1446827, 40) (361707, 40)
# [LightGBM] [Info] Number of positive: 189062, number of negative: 1257765
# [LightGBM] [Debug] Dataset::GetMultiBinFromSparseFeatures: sparse rate 0.915508
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.228367
# [LightGBM] [Debug] init for col-wise cost 0.099018 seconds, init for row-wise cost 0.347279 seconds
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.421000 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6670
# [LightGBM] [Info] Number of data points in the train set: 1446827, number of used features: 40
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.130674 -> initscore=-1.895017
# [LightGBM] [Info] Start training from score -1.895017
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# Training until validation scores don't improve for 100 rounds
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# Did not meet early stopping. Best iteration is:
# [98]	training's auc: 0.99546	training's f1: 0.945266	valid_1's auc: 0.995187	valid_1's f1: 0.944561
# Fold 3 | F1 Score: 0.9862983022169878
# Fold: 4
# (1446827, 40) (361707, 40)
# [LightGBM] [Info] Number of positive: 188498, number of negative: 1258329
# [LightGBM] [Debug] Dataset::GetMultiBinFromSparseFeatures: sparse rate 0.915408
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.228310
# [LightGBM] [Debug] init for col-wise cost 0.123165 seconds, init for row-wise cost 0.383505 seconds
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.456277 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6670
# [LightGBM] [Info] Number of data points in the train set: 1446827, number of used features: 40
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.130284 -> initscore=-1.898453
# [LightGBM] [Info] Start training from score -1.898453
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# Training until validation scores don't improve for 100 rounds
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# Did not meet early stopping. Best iteration is:
# [98]	training's auc: 0.995466	training's f1: 0.944542	valid_1's auc: 0.995336	valid_1's f1: 0.944858
# Fold 4 | F1 Score: 0.986204303483206
# Fold: 5
# (1446828, 40) (361706, 40)
# [LightGBM] [Info] Number of positive: 189123, number of negative: 1257705
# [LightGBM] [Debug] Dataset::GetMultiBinFromSparseFeatures: sparse rate 0.915287
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.228356
# [LightGBM] [Debug] init for col-wise cost 0.152889 seconds, init for row-wise cost 0.354418 seconds
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.433017 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6673
# [LightGBM] [Info] Number of data points in the train set: 1446828, number of used features: 40
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.130716 -> initscore=-1.894646
# [LightGBM] [Info] Start training from score -1.894646
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# Training until validation scores don't improve for 100 rounds
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 130 and max_depth = 14
# Did not meet early stopping. Best iteration is:
# [100]	training's auc: 0.995429	training's f1: 0.945125	valid_1's auc: 0.995475	valid_1's f1: 0.944662
# Fold 5 | F1 Score: 0.9863397344804897
#
# Mean F1 score = 0.9861473437559872
# OOF F1 score = 0.9861473436496079
