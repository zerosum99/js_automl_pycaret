# %%
import warnings
warnings.filterwarnings('ignore')

# %%
pip install pycaret==2.0
# Out:
# WARNING: Ignoring invalid distribution -cipy (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -cipy (/opt/conda/lib/python3.7/site-packages)
# ...
#      |████████████████████████████████| 255 kB 2.2 MB/s eta 0:00:01
# ...
#   Using cached kmodes-0.11.0-py2.py3-none-any.whl (18 kB)
# ...
#   Using cached mlxtend-0.18.0-py2.py3-none-any.whl (1.3 MB)
# ...
#      |████████████████████████████████| 206 kB 5.0 MB/s eta 0:00:01
# ...
#   Using cached umap_learn-0.5.1-py3-none-any.whl
# ...
#      |████████████████████████████████| 69.2 MB 43.7 MB/s eta 0:00:01
# ...
#   Using cached mlflow-1.17.0-py3-none-any.whl (14.2 MB)
# ...
#   Using cached cufflinks-0.17.3-py3-none-any.whl
# ...
#   Using cached nltk-3.6.2-py3-none-any.whl (1.5 MB)
# ...
#      |████████████████████████████████| 23.9 MB 92.5 MB/s eta 0:00:01     |████████████████████████▍       | 18.2 MB 92.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 60 kB 14.0 MB/s eta 0:00:01
# ...
#   Using cached pyod-0.8.9-py3-none-any.whl
# ...

# %%
import re
import os

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline 
import pycaret

# %%
df = pd.read_pickle('/home/work/toy-project/data/lgb_selected.pkl')
# df.drop(['Unnamed: 0'],1,inplace=True)

# %%
df.shape
# Out:
# (1382351, 63)

# %%
from pycaret.classification import *

# %% [markdown]
# ## Make sample
# - Since using original df outrange our RAM capacity
# - Make sample of df for Pycaret to comparing Algorithms

# %%
df_sample = df.copy()
df_sample.sample(frac=0.1, replace=True, random_state=2020)
# Out:
#          int_rate    dti  annual_inc  mo_sin_old_rev_tl_op  \
# 911024      16.02   8.07    132000.0                 231.0
# 1716352     11.49   4.53     40000.0                 167.0
# 22430       12.59  18.42     52000.0                 194.0
# 108560       8.18  24.64     80700.0                 396.0
# 1101730      8.49  15.06     40000.0                  83.0
# ...           ...    ...         ...                   ...
# 134598      17.86  18.22     50000.0                  69.0
# 123921      13.33  24.64    108000.0                 182.0
# 254590      15.61  11.91    150000.0                 157.0
# 571876       7.97   7.54     76682.0                  41.0
# 995876       9.75  24.10     60000.0                 115.0
#
#          acc_open_past_24mths  loan_amnt  emp_length  addr_state  revol_bal  \
# 911024                   10.0    16000.0           1           4     4643.0
# 1716352                   4.0     1000.0           1           4     3755.0
# ...

# %% [markdown]
# ## Setting up Pycaret

# %%
clf = setup(data = df_sample, target = 'loan_status', silent = True)
# Out:
# <style  type="text/css" >
# </style><table id="T_36797_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_36797_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_36797_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_36797_row0_col1" class="data row0 col1" >1719</td>
#             </tr>
#             <tr>
#                         <th id="T_36797_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_36797_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_36797_row1_col1" class="data row1 col1" >loan_status</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# ## Comparing Models

# %%
best_3 = compare_models(sort ='AUC', fold=3, n_select = 3)
# Out:
# <style  type="text/css" >
#     #T_cd2df_ th {
#           text-align: left;
# ...
